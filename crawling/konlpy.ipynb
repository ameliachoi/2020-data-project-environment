# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Using cached konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
# Collecting beautifulsoup4==4.6.0
#   Using cached beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
# Requirement already satisfied: colorama in /opt/anaconda3/lib/python3.7/site-packages (from konlpy) (0.4.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.1.1-cp37-cp37m-macosx_10_9_x86_64.whl (408 kB)
#      |████████████████████████████████| 408 kB 795 kB/s eta 0:00:01
# Requirement already satisfied: lxml>=4.1.0 in /opt/anaconda3/lib/python3.7/site-packages (from konlpy) (4.4.1)
# Collecting tweepy>=3.7.0
#   Using cached tweepy-3.9.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: numpy>=1.6 in /opt/anaconda3/lib/python3.7/site-packages (from konlpy) (1.17.2)
# Collecting typing-extensions; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests[socks]>=2.11.1 in /opt/anaconda3/lib/python3.7/site-packages (from tweepy>=3.7.0->konlpy) (2.22.0)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.10.0 in /opt/anaconda3/lib/python3.7/site-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2019.9.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Installing collected packages: beautifulsoup4, typing-extensions, JPype1, oauthlib, requests-oauthlib, tweepy, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.8.0
#     Uninstalling beautifulsoup4-4.8.0:
#       Successfully uninstalled beautifulsoup4-4.8.0
# Successfully installed JPype1-1.1.1 beautifulsoup4-4.6.0 konlpy-0.5.2 oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.9.0 typing-extensions-3.7.4.3
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
from konlpy.tag import Okt
from collections import Counter

filename = "output_reuse.txt"
f = open(filename, 'r', encoding='utf-8')
news = f.read()

# okt 객체 생성
okt = Okt()
noun = okt.nouns(news)
for i, v in enumerate(noun):
    if len(v) < 2:
        noun.pop(i)

count = Counter(noun)
f.close()

# 명사 빈도 카운트
noun_list = count.most_common(100)
for v in noun_list:
    print(v)

# csv 파일에 저장
with open("noun_list_reuse.csv", "w", newline="", encoding='utf-8') as f:
    csvw = csv.writer(f)
    for v in noun_list:
        csvw.writerow(v)
# Out:
# ('재활용', 822)
# ('재활용품', 148)
# ('폐기물', 103)
# ('배터리', 86)
# ('페트병', 84)
# ('쓰레기', 81)
# ('사업', 81)
# ('수거', 79)
# ('자원', 73)
# ('배출', 66)
# ('분리', 60)
# ('친환경', 57)
# ('플라스틱', 54)
# ('현대', 50)
# ('추진', 39)
# ('처리', 37)
# ('순환', 37)
# ('전기차', 35)
# ('인천', 33)
# ('확대', 32)
# ('사용', 31)
# ('환경부', 31)
# ('시설', 30)
# ('발전', 30)
# ('기술', 30)
# ('업계', 30)
# ('추석', 29)
# ('환경', 29)
# ('소재', 27)
# ('제품', 27)
# ('포장재', 26)
# ('현대차', 25)
# ('코로나', 25)
# ('개최', 24)
# ('업체', 24)
# ('화학', 23)
# ('관리', 23)
# ('협력', 23)
# ('인증', 23)
# ('증가', 22)
# ('수집', 22)
# ('공개', 22)
# ('태양광', 22)
# ('패널', 22)
# ('수원시', 22)
# ('그린', 21)
# ('대책', 21)
# ('새마을', 21)
# ('조성', 21)
# ('개발', 21)
# ('운영', 20)
# ('시범', 20)
# ('빗물', 20)
# ('전용', 20)
# ('시스템', 19)
# ('보조', 19)
# ('조명', 19)
# ('공동', 19)
# ('협약', 19)
# ('최초', 19)
# ('아이스팩', 18)
# ('연휴', 18)
# ('주택', 18)
# ('루브리컨츠', 18)
# ('우수', 17)
# ('뉴딜', 16)
# ('에너지', 16)
# ('비닐', 15)
# ('판매', 15)
# ('재활', 15)
# ('이노', 15)
# ('기아차', 15)
# ('캠페인', 14)
# ('화재', 14)
# ('앞장', 14)
# ('개선', 14)
# ('시장', 14)
# ('신고', 14)
# ('제철', 14)
# ('한국', 13)
# ('청주', 13)
# ('실시', 13)
# ('제로', 13)
# ('획득', 13)
# ('철근', 13)
# ('의류', 12)
# ('구축', 12)
# ('대란', 12)
# ('위해', 12)
# ('무상', 12)
# ('흥국생명', 12)
# ('어려움', 12)
# ('신제품', 12)
# ('화장품', 12)
# ('염태영', 12)
# ('형강', 12)
# ('석탄', 12)
# ('마련', 11)
# ('별장', 11)
# ('김해시', 11)
